# %%
import numpy as np
import matplotlib.pyplot as plt
import TopHat as th
from PIL import Image
import Metrics as roc
import ConcatenationTest as CT

# %%
# Ground Truth
folder_gt = 'DB_Angiograms_134/Results'
concatenated_gt = CT.concatenate_images_from_folder(folder_gt)

# Inputs
input_folder = 'DB_Angiograms_134/Images'
concatenated_input = CT.concatenate_images_from_folder(input_folder)

# Results
output_folder = 'DB_Angiograms_134/PostProcessed'
concatenated_results = CT.concatenate_images_from_folder(output_folder)

# %%
# Results
output_folder = 'DB_Angiograms_134/PostProcessed'
concatenated_results = CT.concatenate_images_from_folder(output_folder)

# %%
plt.figure(figsize=(30,7))
plt.imshow(concatenated_gt)
plt.axis('off')


plt.figure(figsize=(30,7))
plt.imshow(concatenated_results)
plt.axis('off')
# Out:
# (-0.5, 40199.5, 299.5, -0.5)

# %%
roc.metricas_PostProcess(concatenated_results, concatenated_gt)
# Out:
# Se obtuvieron los siguientes resultados:
#
#     Accuracy (ACC):     0.8793674161069206.
#     Sensitivity (TPR):  0.9220761442429134.
#     Specificity (SPC):  0.13798310833439895.
#     Precision (PVV):    0.8793674161069206.
#     Dice Coef (DSC):    0.9352946061040394.
#     Ind Jaccard (IoU):  0.8784539004556159.
