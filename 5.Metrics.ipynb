# %%
import numpy as np
import matplotlib.pyplot as plt
import TopHat as th
from PIL import Image
import RoCurveTest as roc
import ConcatenationTest as CT

# %%
# Ground Truth
folder_gt = '/home/denisse/Downloads/drive/DRIVE/training/1st_manual'
concatenated_gt = CT.concatenate_images_from_folder(folder_gt)

# Inputs
input_folder = '/home/denisse/Downloads/drive/DRIVE/training/images'
concatenated_input = CT.concatenate_images_from_folder(input_folder)

# Results
output_folder = '/home/denisse/Downloads/drive/DRIVE/training/PostProcessed'
concatenated_results = CT.concatenate_images_from_folder(output_folder)

# %%
plt.figure(figsize=(30,7))
plt.imshow(concatenated_gt)
plt.axis('off')


plt.figure(figsize=(30,7))
plt.imshow(concatenated_results)
plt.axis('off')
# Out:
# (-0.5, 11299.5, 583.5, -0.5)

# %%
roc.Precision(concatenated_results, concatenated_gt)
# Out:
# 0.9641584469095689

# %%
roc.CofDice(concatenated_results, concatenated_gt)
# Out:
# 0.9717414551625264

# %%
roc.IndJaccard(concatenated_results, concatenated_gt)
# Out:
# 0.9450361098784933

# %%
roc.Sensitivity(concatenated_results, concatenated_gt)
# Out:
# 0.9794446881501795

# %%
roc.Specificity(concatenated_results, concatenated_gt)
# Out:
# 0.6145888012078333
